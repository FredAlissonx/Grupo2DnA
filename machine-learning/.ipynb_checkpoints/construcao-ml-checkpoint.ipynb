# %% [markdown]
# # Preparação das Bases

# %%
# Importa bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns

from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn import datasets
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import recall_score
from sklearn import tree
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.datasets import make_hastie_10_2

# %%
# Importa Base de Dados
df_ml = pd.read_csv('C:/Users/CB517RL/OneDrive - EY/Desktop/Projeto Academy/churn.csv')
df_ml.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# Substitui variaveis descritivas
df_ml['id_geography'] = df_ml['Geography'].replace({'France': 0, 'Spain': 1, 'Germany': 2})
df_ml['id_gender'] = df_ml['Gender'].replace({'Female': 0, 'Male': 1})

# %%
# Exclui colunas que nao serao utilizadas no modelo
df_ml = df_ml.drop(columns=["Surname", "RowNumber", "Geography", "Gender"])

# %% [markdown]
# ### Dicionário de Colunas
#
# - **CustomerId:** Id da pessoa
# - **CreditScore:** Score de crédito da pessoa
# - **Tenure:** (Pesquisar significado!)
# - **Balance:** Valor disponível em conta
# - **NumOfProducts:** Número de produtos contratados
# - **HasCrCard:** Tem cartão de crédito?
# - **IsActiveMember:** É membro ativo?
# - **EstimatedSalary:** Estimativa de salário
# - **Exited:** Cliente realizou churn?
# - **id_geography:** País de localização
#   - `0`: França
#   - `1`: Espanha
#   - `2`: Alemanha
# - **id_gender:** Gênero da pessoa
#   - `0`: Feminino
#   - `1`: Masculino

# %%
df_ml.head()
# Out:
#    CustomerId  CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0    15634602          619   42       2       0.00              1          1
# 1    15647311          608   41       1   83807.86              1          0
# 2    15619304          502   42       8  159660.80              3          1
# 3    15701354          699   39       1       0.00              2          0
# 4    15737888          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  id_geography  id_gender
# 0               1        101348.88       1             0          0
# 1               1        112542.58       0             1          0
# 2               0        113931.57       1             0          0
# 3               0         93826.63       0             0          0
# 4               1         79084.10       0             1          0

# %% [markdown]
# # Analise de correlacao entre as colunas

# %%
# Análise da correlação entre as colunas
correlation_matrix = df_ml.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='seismic', center=0)
plt.title("Matriz de Correlação")
plt.show()

# %% [markdown]
# # Construção dos Modelos

# %% [markdown]
# ### Definição da variáveis de treino e de teste

# %%
# define a aleatoriedade para separação das bases de treino e de teste
SEED = 5
np.random.seed(SEED)

# %%
# Separa os dados em features e target
x = df_ml[["CreditScore", "Age", "Tenure", "Balance", "NumOfProducts", "HasCrCard", "IsActiveMember", "EstimatedSalary", "id_geography", "id_gender"]] # Features
y = df_ml["Exited"] # Target variable

# %%
# Divide de variaveis de treino e de teste (features e target)
treino_x, teste_x, treino_y, teste_y = train_test_split(x, 
                                                                y, 
                                                                random_state = SEED, 
                                                                test_size = 0.25, 
                                                                stratify = y)

# %%
# Escala as duas variáveis
scaler = MinMaxScaler(feature_range=(0, 1))
treino_x = scaler.fit_transform(treino_x)
teste_x = scaler.fit_transform(teste_x)

# %% [markdown]
# ## Rodando modelos com base geral
# Base apresenta um valor desbalanceado entre o total de registros positivos e negativos para churn. Em primeiro momento os modelos rodarao com a base desbalanceada, no futudo o balanceamento sera realizado para melhorar os resultados dos modelos.

# %% [markdown]
# ### SVC

# %%
svc = SVC()
svc.fit(treino_x, treino_y)
previsoes_svc = svc.predict(teste_x)

# %%
# Acuracia SVC
acuracia = accuracy_score(teste_y, previsoes_svc) * 100
print("A acurácia foi de: %.2f%%" % acuracia)
# Out:
# A acurácia foi de: 85.40%

# %%
# Matriz de confusao SVC
y_true_svc = teste_y
y_pred_svc = previsoes_svc
matriz_de_confusao_svc = confusion_matrix(y_true_svc, y_pred_svc) 
 
plt.figure(figsize=(8, 6))
 
sns.heatmap(matriz_de_confusao_svc, annot=True, fmt='d')
 
plt.title('Matriz de Confusão - SVC')
plt.show()

# %%
matriz_de_confusao_svc
# Out:
# array([[1964,   27],
#        [ 338,  171]], dtype=int64)

# %%
# Recall SVC
recall_svc = recall_score(y_true_svc, y_pred_svc, average=None)
print(recall_svc)
# Out:
# [0.98643898 0.33595285]

# %% [markdown]
# ### KNN (K Neighbors Classifier)

# %%
# Modelo KNN
knn = KNeighborsClassifier()
knn.fit(treino_x, treino_y)
previsoes_knn = knn.predict(teste_x)

# %%
# Acuracia KNN
acuracia_knn = accuracy_score(teste_y, previsoes_knn) * 100
print("A acurácia foi de: %.2f%%" % acuracia_knn)
# Out:
# A acurácia foi de: 81.60%

# %%
# Matriz de confusao KNN
y_true_knn = teste_y
y_pred_knn = previsoes_knn
matriz_de_confusao_knn = confusion_matrix(y_true_knn, y_pred_knn) 
 
plt.figure(figsize=(8, 6))
 
sns.heatmap(matriz_de_confusao_knn, annot=True, fmt='d')
 
plt.title('Matriz de Confusão - KNN')
plt.show()

# %%
matriz_de_confusao_knn
# Out:
# array([[1886,  105],
#        [ 355,  154]], dtype=int64)

# %%
# Recall KNN
recall_knn = recall_score(y_true_knn, y_pred_knn, average=None)
print(recall_knn)
# Out:
# [0.94726268 0.30255403]

# %% [markdown]
# ### Arvore de decisao

# %%
# Defini modelo a ser usado
decisionTree = tree.DecisionTreeClassifier()

# Realiza o fit entre as variáveis de treino
decisionTree.fit(treino_x, treino_y)
previsoes_decisionTree_treino = decisionTree.predict(treino_x)

score_treino = decisionTree.score(treino_x, treino_y)
print(f'O score para variáveis de treino foi de: {score_treino}')
# Out:
# O score para variáveis de treino foi de: 1.0

# %%
# Predicoes para variaveis de teste
previsoes_decisionTree_teste = decisionTree.predict(teste_x)

score_teste = decisionTree.score(teste_x, teste_y)
print(f'O score para variáveis de teste foi de: {score_teste}')
# Out:
# O score para variáveis de teste foi de: 0.8008

# %%
# Calcula a acurácia no conjunto de treino
acuracia_treino = accuracy_score(treino_y, previsoes_decisionTree_treino)
print('Acurácia no conjunto de treino:', acuracia_treino)

# Calcula a acurácia no conjunto de teste
acuracia_teste = accuracy_score(teste_y, previsoes_decisionTree_teste)
print('Acurácia no conjunto de teste:', acuracia_teste)
# Out:
# Acurácia no conjunto de treino: 1.0
# Acurácia no conjunto de teste: 0.8008

# %%
# Matriz de confusao
matriz_de_confusao_tree = confusion_matrix(teste_y, previsoes_decisionTree_teste) 
matriz_de_confusao_tree
# Out:
# array([[1737,  254],
#        [ 244,  265]], dtype=int64)

# %%
# Recall
recall_tree = recall_score(treino_y, previsoes_decisionTree_treino)
print(recall_tree)
# Out:
# 1.0

# %%
# Arvore de decisao
fig, ax = plt.subplots()

tree.plot_tree(decisionTree)

plt.plot()
# Out:
# []

# %% [markdown]
# ### XGBOOST

# %%
xgboost = GradientBoostingClassifier(n_estimators=100, 
                                     learning_rate=1.0, 
                                     max_depth=1, 
                                     random_state=0)
xgboost.fit(treino_x, treino_y)
previsoes_xgboost = xgboost.predict(teste_x)

# %%
# Acuracia xgboost
acuracia_xgboost = accuracy_score(teste_y, previsoes_xgboost) * 100
print("A acurácia foi de: %.2f%%" % acuracia_xgboost)
# Out:
# A acurácia foi de: 85.12%

# %%
# Matriz de confusao XGBOOST
y_true_xgboost = teste_y
y_pred_xgboost = previsoes_xgboost
matriz_de_confusao_xgboost = confusion_matrix(y_true_xgboost, y_pred_xgboost) 
 
plt.figure(figsize=(8, 6))
 
sns.heatmap(matriz_de_confusao_xgboost, annot=True, fmt='d')
 
plt.title('Matriz de Confusão - xgboost')
plt.show()

# %%
matriz_de_confusao_xgboost
# Out:
# array([[1909,   82],
#        [ 290,  219]], dtype=int64)

# %%
# Recall XGBOOST
recall_xgboost = recall_score(y_true_xgboost, y_pred_xgboost, average=None)
print(recall_xgboost)
# Out:
# [0.95881467 0.4302554 ]
